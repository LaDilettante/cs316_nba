# %%
import numpy as np
import pandas as pd

import pickle

# %%
pickle.load(open('../model/training_data.pkl', 'rb'))
# Out:
#                    col_point  col_rebound  col_assist  col_steal  col_block  \
# player
# A.J. Hammons            16.6         11.4         0.7        0.6        4.7
# A.J. Price              17.8          4.2         5.7        0.8        0.0
# Aaron Brooks            19.2          4.6         4.6        1.5        0.2
# Aaron Gordon            16.3         10.5         2.6        1.2        1.4
# Aaron Gray              20.5         14.0         2.5        0.6        2.5
# Acie Law                21.6          4.0         6.0        1.4        0.0
# Adam Morrison           29.3          5.8         1.8        1.1        0.3
# Adreian Payne           23.3         10.3         1.9        0.7        1.3
# Al Horford              19.0         13.6         3.1        1.1        2.6
# Al Thornton             24.9          9.1         0.9        1.9        1.4
# Al-Farouq Aminu         19.2         12.9         1.6        1.7        1.7
# ...

# %%
pickle.load(open('../model/training_data_team.pkl', 'rb'))
# Out:
#                                             col_point  col_rebound  \
# player            college
# A.J. Hammons      Purdue                         16.6         11.4
# A.J. Price        Connecticut                    17.8          4.2
# Aaron Brooks      Oregon                         19.2          4.6
# Aaron Gordon      Arizona                        16.3         10.5
# Aaron Gray        Pittsburgh                     20.5         14.0
# Acie Law          Texas A&M                      21.6          4.0
# Adam Morrison     Gonzaga                        29.3          5.8
# Adreian Payne     Michigan State                 23.3         10.3
# Al Horford        Florida                        19.0         13.6
# Al Thornton       Florida State                  24.9          9.1
# Al-Farouq Aminu   Wake Forest                    19.2         12.9
# Alando Tucker     Wisconsin                      25.7          7.0
# Alec Burks        Colorado                       24.5          7.5
# ...
