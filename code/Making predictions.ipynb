# %%
import pickle

# %%
randomforest_point = pickle.load(open('../model/randomforest_point.pkl', 'rb'))
randomforest_team_point = pickle.load(open('../model/randomforest_team_point.pkl', 'rb'))

# %%
nn_point = pickle.load(open('../model/nearestneighbor_point.pkl', 'rb'))
nn_team_point = pickle.load(open('../model/nearestneighbor_team_point.pkl', 'rb'))

# %%
training_data = pickle.load(open('../model/training_data.pkl', 'rb'))
training_data_team = pickle.load(open('../model/training_data_team.pkl', 'rb'))

# %%
# Features used to train model (without team data)
training_data.head()
# Out:
#               col_point  col_rebound  col_assist  col_steal  col_block  \
# player
# A.J. Hammons       16.6         11.4         0.7        0.6        4.7
# A.J. Price         17.8          4.2         5.7        0.8        0.0
# Aaron Brooks       19.2          4.6         4.6        1.5        0.2
# Aaron Gordon       16.3         10.5         2.6        1.2        1.4
# Aaron Gray         20.5         14.0         2.5        0.6        2.5
#
#               position_C  position_C-F  position_F  position_F-C  \
# player
# A.J. Hammons           1             0           0             0
# A.J. Price             0             0           0             0
# Aaron Brooks           0             0           0             0
# Aaron Gordon           0             0           1             0
# Aaron Gray             1             0           0             0
#
#               position_F-G  position_G  position_G-F
# player
# A.J. Hammons             0           0             0
# A.J. Price               0           1             0
# Aaron Brooks             0           1             0
# Aaron Gordon             0           0             0
# Aaron Gray               0           0             0

# %%
# Prediction for A.J. Hammons's points
print(randomforest_point.predict([[16.6, 11.4, 0.7, 0.6, 4.7, 1, 0, 0, 0, 0, 0, 0]]))
print(nn_point.predict([[16.6, 11.4, 0.7, 0.6, 4.7, 1, 0, 0, 0, 0, 0, 0]]))
# Out:
# [ 2.65067547]
# [ 3.7]

# %%
# Get A.J. Hammons nearest neighbors in terms of points

# Get the neighbor indices, i.e. their row number in the training dataset
neighbor_indices = nn_point.kneighbors(X=[[16.6, 11.4, 0.7, 0.6, 4.7, 1, 0, 0, 0, 0, 0, 0]], n_neighbors=5, return_distance=False)
training_data.iloc[neighbor_indices[0], :].index.values
# Out:
# array(['A.J. Hammons', 'Jeff Withey', 'Hasheem Thabeet', 'Festus Ezeli',
#        'Alex Len'], dtype=object)

# %%
# Features used to train model (with team data)
training_data_team.head()
# Out:
#                           col_point  col_rebound  col_assist  col_steal  \
# player       college
# A.J. Hammons Purdue            16.6         11.4         0.7        0.6
# A.J. Price   Connecticut       17.8          4.2         5.7        0.8
# Aaron Brooks Oregon            19.2          4.6         4.6        1.5
# Aaron Gordon Arizona           16.3         10.5         2.6        1.2
# Aaron Gray   Pittsburgh        20.5         14.0         2.5        0.6
#
#                           col_block  team_win_percentage  team_point  \
# player       college
# A.J. Hammons Purdue             4.7                0.618      2375.0
# A.J. Price   Connecticut        0.0                0.529      2380.0
# Aaron Brooks Oregon             0.2                0.563      2450.0
# Aaron Gordon Arizona            1.4                0.895      2911.0
# Aaron Gray   Pittsburgh         2.5                0.730      2731.0
#
#                           team_opponent_point  team_rebound  team_assist  \
# player       college
# A.J. Hammons Purdue                    2195.0        1249.0        505.0
# A.J. Price   Connecticut               2266.0        1338.0        461.0
# Aaron Brooks Oregon                    2321.0        1093.0        475.0
# Aaron Gordon Arizona                   2268.0        1399.0        528.0
# Aaron Gray   Pittsburgh                2410.0        1399.0        578.0
#
#                           team_steal  team_block  position_C  position_C-F  \
# player       college
# A.J. Hammons Purdue            185.0       177.0           1             0
# A.J. Price   Connecticut       220.0       260.0           0             0
# Aaron Brooks Oregon            148.0        81.0           0             0
# Aaron Gordon Arizona           275.0       131.0           0             0
# Aaron Gray   Pittsburgh        251.0       125.0           1             0
#
#                           position_F  position_F-C  position_F-G  position_G  \
# player       college
# A.J. Hammons Purdue                0             0             0           0
# A.J. Price   Connecticut           0             0             0           1
# Aaron Brooks Oregon                0             0             0           1
# Aaron Gordon Arizona               1             0             0           0
# Aaron Gray   Pittsburgh            0             0             0           0
#
#                           position_G-F
# player       college
# A.J. Hammons Purdue                  0
# A.J. Price   Connecticut             0
# Aaron Brooks Oregon                  0
# Aaron Gordon Arizona                 0
# Aaron Gray   Pittsburgh              0

# %%
# Prediction for A.J. Hammons's points
print(randomforest_team_point.predict([[16.6, 11.4, 0.7, 0.6, 4.7, 0.618, 2375.0, 2195.0, 1249.0, 505.0, 185.0, 177.0, 1, 0, 0, 0, 0, 0, 0]]))
# Out:
# [ 2.66338684]
