# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from plotnine import *

# %%
dat = pd.read_csv("../data/draft.csv", index_col=0)

# %%
dat = dat.rename(columns={'Lg': 'League', 'Rd': 'Round', 'Pk': 'Pick', 'Tm': 'Team', 'Pos': 'Position'})

# %%
dat.head()
# Out:
#     Year League  Round  Pick Team                    Player     Age Position  \
# Rk
# 1   2016    NBA      1     1  PHI     Ben Simmons\simmobe01  19.343      G-F
# 2   2016    NBA      1     2  LAL  Brandon Ingram\ingrabr01  18.299        F
# 3   2016    NBA      1     3  BOS    Jaylen Brown\brownja02  19.247      F-G
# 4   2016    NBA      1     4  PHO   Dragan Bender\bendedr01  18.223        F
# 5   2016    NBA      1     5  MIN        Kris Dunn\dunnkr01  22.103        G
#
#    Born                     College
# Rk
# 1    au  Louisiana State University
# 2    us             Duke University
# 3    us    University of California
# 4    ba                         NaN
# 5    us          Providence College

# %%
dat.query('Year == 2010')
# Out:
#      Year League  Round  Pick Team                        Player     Age  \
# Rk
# 361  2010    NBA      1     1  WAS            John Wall\walljo01  19.296
# 362  2010    NBA      1     2  PHI         Evan Turner\turneev01  21.245
# 363  2010    NBA      1     3  NJN      Derrick Favors\favorde01  18.349
# 364  2010    NBA      1     4  MIN      Wesley Johnson\johnswe01  22.354
# 365  2010    NBA      1     5  SAC    DeMarcus Cousins\couside01  19.320
# 366  2010    NBA      1     6  GSW            Ekpe Udoh\udohek01  23.041
# 367  2010    NBA      1     7  DET         Greg Monroe\monrogr01  20.025
# 368  2010    NBA      1     8  LAC     Al-Farouq Aminu\aminual01  19.281
# 369  2010    NBA      1     9  UTA      Gordon Hayward\haywago01  20.098
# 370  2010    NBA      1    10  IND         Paul George\georgpa01  20.058
# 371  2010    NBA      1    11  NOH        Cole Aldrich\aldrico01  21.241
# 372  2010    NBA      1    12  MEM        Xavier Henry\henryxa01  19.106
# ...

# %%
dat.shape
# Out:
# (1125, 10)

# %%
dat_rookie = pd.read_csv("../data/nbarookiedata.csv", skiprows=1, index_col=0)

# %%
dat_rookie.head()
# Out:
#                        Player  Age   Tm   Lg   Season   G  GS    MP   FG  FGA  \
# Rk
# 1      Alex Abrines\abrinal01   23  OKC  NBA  2016-17  68   6  15.5  2.0  5.0
# 2         Ron Baker\bakerro01   23  NYK  NBA  2016-17  52  13  16.5  1.6  4.2
# 3      Wade Baldwin\baldwwa01   20  MEM  NBA  2016-17  33   1  12.3  1.1  3.5
# 4     Malik Beasley\beaslma01   20  DEN  NBA  2016-17  22   1   7.5  1.5  3.3
# 5   DeAndre' Bembry\bembrde01   22  ATL  NBA  2016-17  38   1   9.8  1.2  2.6
#
#     ...    BLK  TOV   PF  PTS    FG%    2P%    3P%   eFG%    FT%    TS%
# Rk  ...
# 1   ...    0.1  0.5  1.7  6.0  0.393  0.426  0.381  0.531  0.898  0.560
# 2   ...    0.2  1.1  1.4  4.1  0.378  0.450  0.267  0.431  0.651  0.456
# 3   ...    0.2  1.2  1.2  3.2  0.313  0.355  0.136  0.326  0.838  0.404
# 4   ...    0.0  0.4  0.5  3.8  0.452  0.533  0.321  0.514  0.800  0.536
# 5   ...    0.1  0.4  0.6  2.7  0.480  0.575  0.056  0.485  0.375  0.481
#
# [5 rows x 31 columns]

# %%
dat_rookie.columns
# Out:
# Index(['Rk', 'Player', 'Age', 'Tm', 'Lg', 'Season', 'G', 'GS', 'MP', 'FG',
#        'FGA', '2P', '2PA', '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'eFG%',
#        'FT%', 'TS%'],
#       dtype='object')

# %%
dat_rookie.Season.value_counts()
# Out:
# 2016-17    88
# 2005-06    85
# 2014-15    82
# 2011-12    81
# 2006-07    80
# 2013-14    78
# 2012-13    78
# 2015-16    73
# 2004-05    70
# 2001-02    69
# 2000-01    68
# 2003-04    67
# 2010-11    67
# 2002-03    64
# 2007-08    64
# 2008-09    62
# 2009-10    58
# Name: Season, dtype: int64
